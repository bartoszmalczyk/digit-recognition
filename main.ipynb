# %%
import tensorflow as tf
from keras.datasets import mnist
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train_reshaped = x_train.reshape(x_train.shape[0], -1)
x_test_reshaped = x_test.reshape(x_test.shape[0], -1)

x_train_reshaped = x_train_reshaped.astype("float32") / 255
x_test_reshaped = x_test_reshaped.astype("float32") / 255

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(loss = "sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(x_train_reshaped, y_train, epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 401us/step - accuracy: 0.8912 - loss: 0.3904
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 390us/step - accuracy: 0.9423 - loss: 0.2004
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 391us/step - accuracy: 0.9519 - loss: 0.1626
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 392us/step - accuracy: 0.9591 - loss: 0.1415
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 390us/step - accuracy: 0.9633 - loss: 0.1263
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 398us/step - accuracy: 0.9664 - loss: 0.1153
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 378us/step - accuracy: 0.9690 - loss: 0.1066
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 393us/step - accuracy: 0.9714 - loss: 0.1004
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.9732 - loss: 0.0952
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.9741 - loss: 0.0909

# %%
test_loss, test_acc = model.evaluate(x_test_reshaped, y_test)

print(f"\nAccuracy: {test_acc * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - accuracy: 0.9631 - loss: 0.1324
#
# Accuracy: 96.31%
